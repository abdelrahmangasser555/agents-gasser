# %%
import pickle
from langchain.vectorstores import Pinecone
import hashlib
import pinecone
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.chains.query_constructor.base import AttributeInfo
from classes import SelfQueryRetrieverNew
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import Docx2txtLoader
from langchain.document_loaders import TextLoader
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
pinecone.init(api_key="78d15b1b-7659-4683-92f7-b7cfa2a00b06", environment="us-west1-gcp-free")

# %%
docs = []

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=100)

# %%
print(*docs, sep="\n")

# %%
print(len(docs))
# Out:
# 0

# %%
# paths = [
#     "docs/Blockchain/Proof of Stake.docx",
#     "docs/Blockchain/Proof of Work.docx",
#     "docs/Blockchain/Timestamping.docx",
#     "docs/Blockchain/Transaction Fees.docx"
# ]
paths = {
    "blockchain": [
        "docs/Blockchain/Proof of Stake.docx",
        "docs/Blockchain/Proof of Work.docx",
        "docs/Blockchain/Timestamping.docx",
        "docs/Blockchain/Transaction Fees.docx"
    ],
    "Mining": [
        "docs/Mining/Cloud Mining _ Mining Contracts.docx",
        "docs/Mining/Energy consuption and outcomes in environment.docx",
        "docs/Mining/Features of mining.docx",
        "docs/Mining/Hashrate and Mining Difficulty.docx",
        "docs/Mining/Mining Equipment _ Programs.docx",
        "docs/Mining/Mining Pools _ Rewards.docx",
    ],
    "staking": [
        "docs/Staking/Decentralisation and Security.docx",
        "docs/Staking/Risk and Safety.docx",
        "docs/Staking/Staking Pools _ Delegation.docx",
        "docs/Staking/Staking features.docx",
        "docs/Staking/Voting Rights_.docx",
    ],
    "web3.0": [
        "docs/Web 3.0/Decentralized Applications_.docx",
        "docs/Web 3.0/Decentralized Finance (DeFi).docx",
        "docs/Web 3.0/Non-Fungible Tokens (NFTs).docx",
        "docs/Web 3.0/Smart Contracts.docx"
    ]
}

# %%
for category, path in paths.items():
    for p in path:
        doc = Docx2txtLoader(p).load()
        doc = text_splitter.split_documents(doc)
        docs.extend(doc)

# %%
for doc in docs:
    print(doc.page_content)
    print("\n-------------\n\n-------\n")
# Out:
# Proof of Stake
#
# The first idea of proof of stake was proposed on the bitcointalk forum in 2011, but the first digital currency to use this method was Peercoin in 2012, along with ShadowCash and a few other projects.
#
# Proof of Stake is an alternative solution to Proof of Work, which is used in blockchain networks for verifying and adding new transactions to the block chain. Unlike PoW, where miners compete to solve complex puzzles, PoS relies on a different approach that takes into account the stake or ownership of a participant in the cryptocurrency.
#
# -------------
#
# -------
#
# In a Proof of Stake system, validators are selected to create new blocks and validate transactions based on the number of coins they stake or lock as collateral. The more coins a validator holds, the higher the chances of being selected to forge the next block.
#
# ...

# %%
print(len(docs))
# Out:
# 56

# %%
from langchain.vectorstores import Pinecone
import pinecone
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.chains.query_constructor.base import AttributeInfo
from classes import SelfQueryRetrieverNew

# %%
vector_store = Pinecone.from_documents(docs, OpenAIEmbeddings(), index_name="crypto-agent")
